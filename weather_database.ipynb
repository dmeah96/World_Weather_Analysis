# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
from config import weather_api_key
import requests
from datetime import datetime
from scipy.stats import linregress
# Dependencies and Setup
import pandas as pd
import requests
import gmaps

# Import API key
from config import g_key

# Configure gmaps API key
gmaps.configure(api_key=g_key)

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 743

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Run an API request for each of the cities.
url= "https://api.openweathermap.org/data/2.5/weather?q="



for i, city in enumerate(cities):
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
#     print('City:',city)
    city = city.replace(" ","+")   
    city_url = url + city +  "&appid=" + weather_api_key
#     city_url = url + cities[0] + "&appid=" + weather_api_key
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Parse the JSON and retrieve data.
    try: 
        city_weather = requests.get(city_url).json()
        print(city_weather)

        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description= city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                            "Lat": city_lat,
                            "Lng": city_lng,
                            "Max Temp": city_max_temp,
                            "Humidity": city_humidity,
                            "Cloudiness": city_clouds,
                            "Wind Speed": city_wind,
                            "Country": city_country,
                            "Date": city_date,
                            "Description": city_description})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | rikitea
# {'coord': {'lon': -134.9692, 'lat': -23.1203}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'}], 'base': 'stations', 'main': {'temp': 296.64, 'feels_like': 296.9, 'temp_min': 296.64, 'temp_max': 296.64, 'pressure': 1018, 'humidity': 71, 'sea_level': 1018, 'grnd_level': 1015}, 'visibility': 10000, 'wind': {'speed': 6.39, 'deg': 41, 'gust': 6.37}, 'rain': {'1h': 0.46}, 'clouds': {'all': 52}, 'dt': 1631835782, 'sys': {'country': 'PF', 'sunrise': 1631804112, 'sunset': 1631847249}, 'timezone': -32400, 'id': 4030556, 'name': 'Rikitea', 'cod': 200}
# Processing Record 2 of Set 1 | cape+town
# {'coord': {'lon': 18.4232, 'lat': -33.9258}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 286.42, 'feels_like': 285.66, 'temp_min': 285.43, 'temp_max': 286.42, 'pressure': 1028, 'humidity': 71}, 'visibility': 10000, 'wind': {'speed': 1.79, 'deg': 0, 'gust': 3.58}, 'clouds': {'all': 0}, 'dt': 1631835842, 'sys': {'type': 2, 'id': 2033665, 'country': 'ZA', 'sunrise': 1631853769, 'sunset': 1631896739}, 'timezone': 7200, 'id': 3369157, 'name': 'Cape Town', 'cod': 200}
# Processing Record 3 of Set 1 | mataura
# {'coord': {'lon': 168.8643, 'lat': -46.1927}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 280.64, 'feels_like': 278.82, 'temp_min': 280.64, 'temp_max': 280.64, 'pressure': 1018, 'humidity': 51, 'sea_level': 1018, 'grnd_level': 1012}, 'visibility': 10000, 'wind': {'speed': 2.74, 'deg': 87, 'gust': 4.07}, 'clouds': {'all': 32}, 'dt': 1631835989, 'sys': {'type': 2, 'id': 2008959, 'country': 'NZ', 'sunrise': 1631817860, 'sunset': 1631860454}, 'timezone': 43200, 'id': 6201424, 'name': 'Mataura', 'cod': 200}
# Processing Record 4 of Set 1 | victoria
# {'coord': {'lon': 114.1577, 'lat': 22.2855}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'}], 'base': 'stations', 'main': {'temp': 302.15, 'feels_like': 308.33, 'temp_min': 301.13, 'temp_max': 302.22, 'pressure': 1009, 'humidity': 82}, 'visibility': 10000, 'wind': {'speed': 0.45, 'deg': 348, 'gust': 1.34}, 'rain': {'1h': 0.18}, 'clouds': {'all': 52}, 'dt': 1631836276, 'sys': {'type': 2, 'id': 2035800, 'country': 'HK', 'sunrise': 1631830241, 'sunset': 1631874326}, 'timezone': 28800, 'id': 1819729, 'name': 'Hong Kong', 'cod': 200}
# Processing Record 5 of Set 1 | mahebourg
# {'coord': {'lon': 57.7, 'lat': -20.4081}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 294.31, 'feels_like': 294.94, 'temp_min': 293.85, 'temp_max': 294.31, 'pressure': 1017, 'humidity': 94}, 'visibility': 10000, 'wind': {'speed': 1.54, 'deg': 20}, 'clouds': {'all': 75}, 'dt': 1631835980, 'sys': {'type': 1, 'id': 2061, 'country': 'MU', 'sunrise': 1631844217, 'sunset': 1631887442}, 'timezone': 14400, 'id': 934322, 'name': 'Mahébourg', 'cod': 200}
# Processing Record 6 of Set 1 | khatanga
# {'coord': {'lon': 102.5, 'lat': 71.9667}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 273.02, 'feels_like': 271.08, 'temp_min': 273.02, 'temp_max': 273.02, 'pressure': 1018, 'humidity': 89, 'sea_level': 1018, 'grnd_level': 1014}, 'visibility': 4087, 'wind': {'speed': 1.61, 'deg': 54, 'gust': 2.2}, 'clouds': {'all': 100}, 'dt': 1631835741, 'sys': {'country': 'RU', 'sunrise': 1631831137, 'sunset': 1631879024}, 'timezone': 25200, 'id': 2022572, 'name': 'Khatanga', 'cod': 200}
# Processing Record 7 of Set 1 | dikson
# {'coord': {'lon': 80.5464, 'lat': 73.5069}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 274.89, 'feels_like': 269.33, 'temp_min': 274.89, 'temp_max': 274.89, 'pressure': 1022, 'humidity': 77, 'sea_level': 1022, 'grnd_level': 1016}, 'visibility': 10000, 'wind': {'speed': 7.36, 'deg': 57, 'gust': 8.05}, 'clouds': {'all': 100}, 'dt': 1631836078, 'sys': {'country': 'RU', 'sunrise': 1631836194, 'sunset': 1631884502}, 'timezone': 25200, 'id': 1507390, 'name': 'Dikson', 'cod': 200}
# Processing Record 8 of Set 1 | henties+bay
# {'coord': {'lon': 14.2845, 'lat': -22.116}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}], 'base': 'stations', 'main': {'temp': 284.18, 'feels_like': 283.69, 'temp_min': 284.18, 'temp_max': 284.18, 'pressure': 1015, 'humidity': 90, 'sea_level': 1015, 'grnd_level': 1012}, 'visibility': 10000, 'wind': {'speed': 1.13, 'deg': 145, 'gust': 1.49}, 'clouds': {'all': 16}, 'dt': 1631835984, 'sys': {'type': 2, 'id': 2012545, 'country': 'NA', 'sunrise': 1631854646, 'sunset': 1631897848}, 'timezone': 7200, 'id': 3356832, 'name': 'Henties Bay', 'cod': 200}
# Processing Record 9 of Set 1 | pirgos
# {'coord': {'lon': 25.7178, 'lat': 35.1167}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 295.64, 'feels_like': 295.33, 'temp_min': 294.97, 'temp_max': 298.42, 'pressure': 1016, 'humidity': 53, 'sea_level': 1016, 'grnd_level': 1011}, 'visibility': 10000, 'wind': {'speed': 3.91, 'deg': 315, 'gust': 6.3}, 'clouds': {'all': 0}, 'dt': 1631836031, 'sys': {'type': 1, 'id': 6616, 'country': 'GR', 'sunrise': 1631851287, 'sunset': 1631895720}, 'timezone': 10800, 'id': 261814, 'name': 'Pirgos', 'cod': 200}
# Processing Record 10 of Set 1 | illoqqortoormiut
# {'cod': '404', 'message': 'city not found'}
# City not found. Skipping...
# Processing Record 11 of Set 1 | atuona
# {'coord': {'lon': -139.0333, 'lat': -9.8}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'}], 'base': 'stations', 'main': {'temp': 298.28, 'feels_like': 298.91, 'temp_min': 298.28, 'temp_max': 298.28, 'pressure': 1012, 'humidity': 79, 'sea_level': 1012, 'grnd_level': 1004}, 'visibility': 10000, 'wind': {'speed': 7.11, 'deg': 94, 'gust': 7.66}, 'rain': {'1h': 0.23}, 'clouds': {'all': 18}, 'dt': 1631836048, 'sys': {'country': 'PF', 'sunrise': 1631804954, 'sunset': 1631848358}, 'timezone': -34200, 'id': 4020109, 'name': 'Atuona', 'cod': 200}
# Processing Record 12 of Set 1 | qui+nhon
# {'coord': {'lon': 109.2333, 'lat': 13.7667}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 299.68, 'feels_like': 299.68, 'temp_min': 299.68, 'temp_max': 299.68, 'pressure': 1010, 'humidity': 86, 'sea_level': 1010, 'grnd_level': 1010}, 'visibility': 10000, 'wind': {'speed': 1.38, 'deg': 235, 'gust': 1.61}, 'clouds': {'all': 75}, 'dt': 1631836285, 'sys': {'country': 'VN', 'sunrise': 1631831525, 'sunset': 1631875405}, 'timezone': 25200, 'id': 1568574, 'name': 'Qui Nhon', 'cod': 200}
# Processing Record 13 of Set 1 | gambela
# {'coord': {'lon': 34.5833, 'lat': 8.25}, 'weather': [{'id': 501, 'main': 'Rain', 'description': 'moderate rain', 'icon': '10n'}], 'base': 'stations', 'main': {'temp': 294.09, 'feels_like': 294.77, 'temp_min': 294.09, 'temp_max': 294.09, 'pressure': 1009, 'humidity': 97, 'sea_level': 1009, 'grnd_level': 959}, 'visibility': 8173, 'wind': {'speed': 1.59, 'deg': 72, 'gust': 1.87}, 'rain': {'1h': 1.19}, 'clouds': {'all': 100}, 'dt': 1631836361, 'sys': {'country': 'ET', 'sunrise': 1631849498, 'sunset': 1631893255}, 'timezone': 10800, 'id': 337405, 'name': 'Gambēla', 'cod': 200}
# Processing Record 14 of Set 1 | tura
# {'coord': {'lon': 90.2201, 'lat': 25.5198}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 295.29, 'feels_like': 296.04, 'temp_min': 295.29, 'temp_max': 295.29, 'pressure': 1006, 'humidity': 95, 'sea_level': 1006, 'grnd_level': 963}, 'visibility': 10000, 'wind': {'speed': 1.41, 'deg': 132, 'gust': 1.89}, 'clouds': {'all': 99}, 'dt': 1631836246, 'sys': {'country': 'IN', 'sunrise': 1631835945, 'sunset': 1631880109}, 'timezone': 19800, 'id': 1254046, 'name': 'Tura', 'cod': 200}
# Processing Record 15 of Set 1 | hermanus
# {'coord': {'lon': 19.2345, 'lat': -34.4187}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}], 'base': 'stations', 'main': {'temp': 283.6, 'feels_like': 282.69, 'temp_min': 283.6, 'temp_max': 283.6, 'pressure': 1028, 'humidity': 76, 'sea_level': 1028, 'grnd_level': 1025}, 'visibility': 10000, 'wind': {'speed': 3.8, 'deg': 49, 'gust': 4.21}, 'clouds': {'all': 18}, 'dt': 1631835994, 'sys': {'type': 2, 'id': 2006131, 'country': 'ZA', 'sunrise': 1631853579, 'sunset': 1631896539}, 'timezone': 7200, 'id': 3366880, 'name': 'Hermanus', 'cod': 200}
# Processing Record 16 of Set 1 | port+macquarie
# {'coord': {'lon': 152.9167, 'lat': -31.4333}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 289.13, 'feels_like': 288.3, 'temp_min': 289.13, 'temp_max': 289.13, 'pressure': 1023, 'humidity': 58, 'sea_level': 1023, 'grnd_level': 1022}, 'visibility': 10000, 'wind': {'speed': 2.42, 'deg': 64, 'gust': 2.69}, 'clouds': {'all': 0}, 'dt': 1631836362, 'sys': {'type': 1, 'id': 9610, 'country': 'AU', 'sunrise': 1631821494, 'sunset': 1631864473}, 'timezone': 36000, 'id': 2152659, 'name': 'Port Macquarie', 'cod': 200}
# Processing Record 17 of Set 1 | georgetown
# {'coord': {'lon': 100.3354, 'lat': 5.4112}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 299.85, 'feels_like': 302.39, 'temp_min': 299.12, 'temp_max': 300.31, 'pressure': 1009, 'humidity': 82}, 'visibility': 7000, 'wind': {'speed': 1.54, 'deg': 60}, 'clouds': {'all': 40}, 'dt': 1631836269, 'sys': {'type': 2, 'id': 2037578, 'country': 'MY', 'sunrise': 1631833748, 'sunset': 1631877452}, 'timezone': 28800, 'id': 1735106, 'name': 'George Town', 'cod': 200}
# Processing Record 18 of Set 1 | khonuu
# {'cod': '404', 'message': 'city not found'}
# City not found. Skipping...
# Processing Record 19 of Set 1 | sokoto
# {'coord': {'lon': 5.239, 'lat': 13.0609}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 297.16, 'feels_like': 297.76, 'temp_min': 297.16, 'temp_max': 297.16, 'pressure': 1013, 'humidity': 82, 'sea_level': 1013, 'grnd_level': 979}, 'visibility': 10000, 'wind': {'speed': 5.33, 'deg': 209, 'gust': 8.31}, 'clouds': {'all': 64}, 'dt': 1631836363, 'sys': {'country': 'NG', 'sunrise': 1631856491, 'sunset': 1631900344}, 'timezone': 3600, 'id': 2322911, 'name': 'Sokoto', 'cod': 200}
# Processing Record 20 of Set 1 | barrow
# {'coord': {'lon': -156.7887, 'lat': 71.2906}, 'weather': [{'id': 600, 'main': 'Snow', 'description': 'light snow', 'icon': '13d'}, {'id': 701, 'main': 'Mist', 'description': 'mist', 'icon': '50d'}, {'id': 501, 'main': 'Rain', 'description': 'moderate rain', 'icon': '10d'}], 'base': 'stations', 'main': {'temp': 274.16, 'feels_like': 269.42, 'temp_min': 274.16, 'temp_max': 274.16, 'pressure': 1004, 'humidity': 93}, 'visibility': 4828, 'wind': {'speed': 5.14, 'deg': 60}, 'rain': {'1h': 1.52}, 'clouds': {'all': 90}, 'dt': 1631836039, 'sys': {'type': 1, 'id': 7649, 'country': 'US', 'sunrise': 1631806983, 'sunset': 1631854849}, 'timezone': -28800, 'id': 5880054, 'name': 'Barrow', 'cod': 200}
# Processing Record 21 of Set 1 | hilo
# {'coord': {'lon': -155.09, 'lat': 19.7297}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 300.11, 'feels_like': 302.53, 'temp_min': 298.77, 'temp_max': 302.19, 'pressure': 1018, 'humidity': 77}, 'visibility': 10000, 'wind': {'speed': 3.09, 'deg': 0}, 'clouds': {'all': 90}, 'dt': 1631835982, 'sys': {'type': 1, 'id': 7881, 'country': 'US', 'sunrise': 1631808490, 'sunset': 1631852527}, 'timezone': -36000, 'id': 5855927, 'name': 'Hilo', 'cod': 200}
# Processing Record 22 of Set 1 | chokurdakh
# {'coord': {'lon': 147.9167, 'lat': 70.6333}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 278.43, 'feels_like': 278.43, 'temp_min': 278.43, 'temp_max': 278.43, 'pressure': 1005, 'humidity': 77, 'sea_level': 1005, 'grnd_level': 1002}, 'visibility': 10000, 'wind': {'speed': 0.96, 'deg': 270, 'gust': 1.78}, 'clouds': {'all': 99}, 'dt': 1631835991, 'sys': {'country': 'RU', 'sunrise': 1631820375, 'sunset': 1631867991}, 'timezone': 39600, 'id': 2126123, 'name': 'Chokurdakh', 'cod': 200}
# Processing Record 23 of Set 1 | butaritari
# {'coord': {'lon': 172.7902, 'lat': 3.0707}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'}], 'base': 'stations', 'main': {'temp': 301.15, 'feels_like': 304.65, 'temp_min': 301.15, 'temp_max': 301.15, 'pressure': 1010, 'humidity': 76, 'sea_level': 1010, 'grnd_level': 1009}, 'visibility': 10000, 'wind': {'speed': 7.13, 'deg': 117, 'gust': 7.33}, 'rain': {'1h': 0.23}, 'clouds': {'all': 33}, 'dt': 1631835783, 'sys': {'country': 'KI', 'sunrise': 1631816385, 'sunset': 1631860045}, 'timezone': 43200, 'id': 2110227, 'name': 'Butaritari', 'cod': 200}
# Processing Record 24 of Set 1 | vaini
# {'coord': {'lon': -175.2, 'lat': -21.2}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}], 'base': 'stations', 'main': {'temp': 300.24, 'feels_like': 304.03, 'temp_min': 300.24, 'temp_max': 300.24, 'pressure': 1018, 'humidity': 89}, 'visibility': 10000, 'wind': {'speed': 3.6, 'deg': 60}, 'clouds': {'all': 20}, 'dt': 1631836010, 'sys': {'type': 1, 'id': 7285, 'country': 'TO', 'sunrise': 1631900083, 'sunset': 1631943340}, 'timezone': 46800, 'id': 4032243, 'name': 'Vaini', 'cod': 200}
# Processing Record 25 of Set 1 | hobart
# {'coord': {'lon': 147.3294, 'lat': -42.8794}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': 285.15, 'feels_like': 284.08, 'temp_min': 283.3, 'temp_max': 285.96, 'pressure': 1013, 'humidity': 64}, 'visibility': 10000, 'wind': {'speed': 1.79, 'deg': 68, 'gust': 4.02}, 'clouds': {'all': 20}, 'dt': 1631836294, 'sys': {'type': 2, 'id': 2002195, 'country': 'AU', 'sunrise': 1631822973, 'sunset': 1631865675}, 'timezone': 36000, 'id': 2163355, 'name': 'Hobart', 'cod': 200}
# Processing Record 26 of Set 1 | cherskiy
# {'coord': {'lon': 161.3, 'lat': 68.75}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 277.66, 'feels_like': 272.9, 'temp_min': 277.66, 'temp_max': 277.66, 'pressure': 1010, 'humidity': 58, 'sea_level': 1010, 'grnd_level': 1010}, 'visibility': 10000, 'wind': {'speed': 7.36, 'deg': 166, 'gust': 8.42}, 'clouds': {'all': 90}, 'dt': 1631836365, 'sys': {'country': 'RU', 'sunrise': 1631817362, 'sunset': 1631864582}, 'timezone': 39600, 'id': 2126199, 'name': 'Cherskiy', 'cod': 200}
# Processing Record 27 of Set 1 | yellowknife
# {'coord': {'lon': -114.3525, 'lat': 62.456}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': 282.44, 'feels_like': 280.48, 'temp_min': 282.44, 'temp_max': 282.44, 'pressure': 1010, 'humidity': 49}, 'visibility': 10000, 'wind': {'speed': 3.6, 'deg': 360}, 'clouds': {'all': 20}, 'dt': 1631835981, 'sys': {'type': 1, 'id': 1007, 'country': 'CA', 'sunrise': 1631797575, 'sunset': 1631843893}, 'timezone': -21600, 'id': 6185377, 'name': 'Yellowknife', 'cod': 200}
# Processing Record 28 of Set 1 | ushuaia
# {'coord': {'lon': -68.3, 'lat': -54.8}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 275.96, 'feels_like': 275.96, 'temp_min': 275.96, 'temp_max': 275.96, 'pressure': 1004, 'humidity': 60}, 'visibility': 10000, 'wind': {'speed': 0, 'deg': 0}, 'clouds': {'all': 75}, 'dt': 1631835783, 'sys': {'type': 1, 'id': 8303, 'country': 'AR', 'sunrise': 1631788587, 'sunset': 1631830782}, 'timezone': -10800, 'id': 3833367, 'name': 'Ushuaia', 'cod': 200}
# Processing Record 29 of Set 1 | bredasdorp
# {'coord': {'lon': 20.0403, 'lat': -34.5322}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 283.77, 'feels_like': 283.16, 'temp_min': 283.31, 'temp_max': 283.77, 'pressure': 1029, 'humidity': 87}, 'visibility': 10000, 'wind': {'speed': 1.54, 'deg': 360}, 'clouds': {'all': 8}, 'dt': 1631835725, 'sys': {'type': 1, 'id': 1966, 'country': 'ZA', 'sunrise': 1631853387, 'sunset': 1631896344}, 'timezone': 7200, 'id': 1015776, 'name': 'Bredasdorp', 'cod': 200}
# Processing Record 30 of Set 1 | nikolskoye
# {'coord': {'lon': 30.7861, 'lat': 59.7035}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'stations', 'main': {'temp': 278.09, 'feels_like': 278.09, 'temp_min': 277.6, 'temp_max': 278.09, 'pressure': 1022, 'humidity': 94, 'sea_level': 1022, 'grnd_level': 1018}, 'visibility': 10000, 'wind': {'speed': 0.38, 'deg': 50, 'gust': 0.36}, 'clouds': {'all': 25}, 'dt': 1631836042, 'sys': {'type': 1, 'id': 8926, 'country': 'RU', 'sunrise': 1631849381, 'sunset': 1631895194}, 'timezone': 10800, 'id': 546105, 'name': 'Nikolskoye', 'cod': 200}
# Processing Record 31 of Set 1 | longyearbyen
# {'coord': {'lon': 15.6401, 'lat': 78.2186}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}], 'base': 'stations', 'main': {'temp': 278.06, 'feels_like': 275.88, 'temp_min': 278.06, 'temp_max': 278.06, 'pressure': 1017, 'humidity': 81}, 'visibility': 10000, 'wind': {'speed': 2.57, 'deg': 240}, 'clouds': {'all': 75}, 'dt': 1631836366, 'sys': {'type': 1, 'id': 1663, 'country': 'SJ', 'sunrise': 1631850778, 'sunset': 1631901065}, 'timezone': 7200, 'id': 2729907, 'name': 'Longyearbyen', 'cod': 200}
# Processing Record 32 of Set 1 | mareeba
# {'coord': {'lon': 145.4333, 'lat': -17}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 296.2, 'feels_like': 296.21, 'temp_min': 295.55, 'temp_max': 297.86, 'pressure': 1019, 'humidity': 63, 'sea_level': 1019, 'grnd_level': 973}, 'visibility': 10000, 'wind': {'speed': 4.08, 'deg': 87, 'gust': 7.12}, 'clouds': {'all': 29}, 'dt': 1631836210, 'sys': {'type': 2, 'id': 2010006, 'country': 'AU', 'sunrise': 1631823142, 'sunset': 1631866416}, 'timezone': 36000, 'id': 2158767, 'name': 'Mareeba', 'cod': 200}
# Processing Record 33 of Set 1 | pisco
# {'coord': {'lon': -76.2167, 'lat': -13.7}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}], 'base': 'stations', 'main': {'temp': 290.18, 'feels_like': 289.95, 'temp_min': 289.83, 'temp_max': 290.18, 'pressure': 1014, 'humidity': 77}, 'visibility': 10000, 'wind': {'speed': 6.17, 'deg': 220}, 'clouds': {'all': 20}, 'dt': 1631836222, 'sys': {'type': 1, 'id': 8691, 'country': 'PE', 'sunrise': 1631789924, 'sunset': 1631833244}, 'timezone': -18000, 'id': 3932145, 'name': 'Pisco', 'cod': 200}
# Processing Record 34 of Set 1 | amderma
# {'cod': '404', 'message': 'city not found'}
# City not found. Skipping...
# Processing Record 35 of Set 1 | punta+arenas
# {'coord': {'lon': -70.9167, 'lat': -53.15}, 'weather': [{'id': 300, 'main': 'Drizzle', 'description': 'light intensity drizzle', 'icon': '09n'}, {'id': 701, 'main': 'Mist', 'description': 'mist', 'icon': '50n'}], 'base': 'stations', 'main': {'temp': 276.21, 'feels_like': 271.74, 'temp_min': 276.21, 'temp_max': 276.21, 'pressure': 1002, 'humidity': 93}, 'visibility': 4000, 'wind': {'speed': 5.66, 'deg': 90}, 'clouds': {'all': 90}, 'dt': 1631835542, 'sys': {'type': 1, 'id': 8487, 'country': 'CL', 'sunrise': 1631789177, 'sunset': 1631831447}, 'timezone': -10800, 'id': 3874787, 'name': 'Punta Arenas', 'cod': 200}
# Processing Record 36 of Set 1 | alofi
# {'coord': {'lon': -169.9187, 'lat': -19.0595}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'}], 'base': 'stations', 'main': {'temp': 301.09, 'feels_like': 304.24, 'temp_min': 301.09, 'temp_max': 301.09, 'pressure': 1017, 'humidity': 74}, 'visibility': 10000, 'wind': {'speed': 6.69, 'deg': 100}, 'rain': {'1h': 0.15}, 'clouds': {'all': 75}, 'dt': 1631836192, 'sys': {'type': 1, 'id': 7306, 'country': 'NU', 'sunrise': 1631812453, 'sunset': 1631855680}, 'timezone': -39600, 'id': 4036284, 'name': 'Alofi', 'cod': 200}
# Processing Record 37 of Set 1 | ponta+do+sol
# {'coord': {'lon': -17.1, 'lat': 32.6667}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}], 'base': 'stations', 'main': {'temp': 295.11, 'feels_like': 295.14, 'temp_min': 294.66, 'temp_max': 296.5, 'pressure': 1023, 'humidity': 68, 'sea_level': 1023, 'grnd_level': 1023}, 'visibility': 10000, 'wind': {'speed': 3.05, 'deg': 24, 'gust': 3.81}, 'clouds': {'all': 17}, 'dt': 1631836055, 'sys': {'type': 2, 'id': 2008291, 'country': 'PT', 'sunrise': 1631861608, 'sunset': 1631905947}, 'timezone': 3600, 'id': 2264557, 'name': 'Ponta do Sol', 'cod': 200}
# Processing Record 38 of Set 1 | faya
# {'coord': {'lon': 42.4509, 'lat': 18.3851}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'stations', 'main': {'temp': 291.44, 'feels_like': 290.68, 'temp_min': 291.21, 'temp_max': 291.44, 'pressure': 1011, 'humidity': 52, 'sea_level': 1011, 'grnd_level': 787}, 'visibility': 10000, 'wind': {'speed': 0.98, 'deg': 120, 'gust': 1.56}, 'clouds': {'all': 45}, 'dt': 1631836231, 'sys': {'type': 1, 'id': 7396, 'country': 'SA', 'sunrise': 1631847501, 'sunset': 1631891476}, 'timezone': 10800, 'id': 110690, 'name': 'Faya', 'cod': 200}
# Processing Record 39 of Set 1 | lima
# {'coord': {'lon': -77.0282, 'lat': -12.0432}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 288.29, 'feels_like': 287.87, 'temp_min': 287.67, 'temp_max': 288.29, 'pressure': 1014, 'humidity': 77}, 'visibility': 8000, 'wind': {'speed': 3.09, 'deg': 220}, 'clouds': {'all': 90}, 'dt': 1631835780, 'sys': {'type': 1, 'id': 8682, 'country': 'PE', 'sunrise': 1631790102, 'sunset': 1631833455}, 'timezone': -18000, 'id': 3936456, 'name': 'Lima', 'cod': 200}
# Processing Record 40 of Set 1 | salinas
# {'coord': {'lon': -121.6555, 'lat': 36.6777}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 289.63, 'feels_like': 289.21, 'temp_min': 287.17, 'temp_max': 297.12, 'pressure': 1012, 'humidity': 72}, 'visibility': 10000, 'wind': {'speed': 6.69, 'deg': 330}, 'clouds': {'all': 75}, 'dt': 1631836369, 'sys': {'type': 1, 'id': 5885, 'country': 'US', 'sunrise': 1631800202, 'sunset': 1631844771}, 'timezone': -25200, 'id': 5391295, 'name': 'Salinas', 'cod': 200}
# Processing Record 41 of Set 1 | carnarvon
# {'coord': {'lon': 113.6333, 'lat': -24.8667}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 285.19, 'feels_like': 284.17, 'temp_min': 285.19, 'temp_max': 285.19, 'pressure': 1021, 'humidity': 66}, 'visibility': 10000, 'wind': {'speed': 4.12, 'deg': 140}, 'clouds': {'all': 31}, 'dt': 1631836089, 'sys': {'type': 1, 'id': 9505, 'country': 'AU', 'sunrise': 1631830846, 'sunset': 1631873973}, 'timezone': 28800, 'id': 2074865, 'name': 'Carnarvon', 'cod': 200}
# Processing Record 42 of Set 1 | castro
# {'coord': {'lon': -50.0119, 'lat': -24.7911}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 285.3, 'feels_like': 285.1, 'temp_min': 285.3, 'temp_max': 285.3, 'pressure': 1026, 'humidity': 97, 'sea_level': 1026, 'grnd_level': 911}, 'visibility': 69, 'wind': {'speed': 3.93, 'deg': 97, 'gust': 11}, 'clouds': {'all': 100}, 'dt': 1631836090, 'sys': {'country': 'BR', 'sunrise': 1631783755, 'sunset': 1631826837}, 'timezone': -10800, 'id': 3466704, 'name': 'Castro', 'cod': 200}
# Processing Record 43 of Set 1 | hithadhoo
# {'coord': {'lon': 73.0833, 'lat': -0.6}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 301.63, 'feels_like': 305.09, 'temp_min': 301.63, 'temp_max': 301.63, 'pressure': 1009, 'humidity': 72, 'sea_level': 1009, 'grnd_level': 1008}, 'visibility': 10000, 'wind': {'speed': 4.24, 'deg': 266, 'gust': 4.51}, 'clouds': {'all': 99}, 'dt': 1631836079, 'sys': {'country': 'MV', 'sunrise': 1631840345, 'sunset': 1631883933}, 'timezone': 18000, 'id': 1282256, 'name': 'Hithadhoo', 'cod': 200}
# Processing Record 44 of Set 1 | upernavik
# {'coord': {'lon': -56.1549, 'lat': 72.7868}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 269.73, 'feels_like': 266.3, 'temp_min': 269.73, 'temp_max': 269.73, 'pressure': 1009, 'humidity': 55, 'sea_level': 1009, 'grnd_level': 1009}, 'visibility': 10000, 'wind': {'speed': 2.31, 'deg': 75, 'gust': 2.22}, 'clouds': {'all': 100}, 'dt': 1631835978, 'sys': {'country': 'GL', 'sunrise': 1631782538, 'sunset': 1631831002}, 'timezone': -7200, 'id': 3418910, 'name': 'Upernavik', 'cod': 200}
# Processing Record 45 of Set 1 | portland
# {'coord': {'lon': -122.6762, 'lat': 45.5234}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 297.1, 'feels_like': 296.23, 'temp_min': 295.31, 'temp_max': 298.89, 'pressure': 1014, 'humidity': 26}, 'visibility': 10000, 'wind': {'speed': 1.34, 'deg': 24, 'gust': 4.02}, 'clouds': {'all': 1}, 'dt': 1631836207, 'sys': {'type': 2, 'id': 2008548, 'country': 'US', 'sunrise': 1631800251, 'sunset': 1631845212}, 'timezone': -25200, 'id': 5746545, 'name': 'Portland', 'cod': 200}
# Processing Record 46 of Set 1 | lagoa
# {'coord': {'lon': -27.9833, 'lat': 39.05}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'stations', 'main': {'temp': 294.46, 'feels_like': 295.02, 'temp_min': 294.46, 'temp_max': 294.46, 'pressure': 1028, 'humidity': 91, 'sea_level': 1028, 'grnd_level': 1019}, 'visibility': 10000, 'wind': {'speed': 5.97, 'deg': 27, 'gust': 6.1}, 'clouds': {'all': 49}, 'dt': 1631836069, 'sys': {'country': 'PT', 'sunrise': 1631777660, 'sunset': 1631822362}, 'timezone': 0, 'id': 3372964, 'name': 'Lagoa', 'cod': 200}
# Processing Record 47 of Set 1 | busselton
# {'coord': {'lon': 115.3333, 'lat': -33.65}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 284.63, 'feels_like': 283.64, 'temp_min': 284.63, 'temp_max': 284.63, 'pressure': 1022, 'humidity': 69, 'sea_level': 1022, 'grnd_level': 1021}, 'visibility': 10000, 'wind': {'speed': 2.42, 'deg': 228, 'gust': 5.73}, 'clouds': {'all': 75}, 'dt': 1631835971, 'sys': {'country': 'AU', 'sunrise': 1631830530, 'sunset': 1631873473}, 'timezone': 28800, 'id': 2075265, 'name': 'Busselton', 'cod': 200}
# Processing Record 48 of Set 1 | lompoc
# {'coord': {'lon': -120.4579, 'lat': 34.6391}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 291.71, 'feels_like': 291.55, 'temp_min': 289.04, 'temp_max': 296.24, 'pressure': 1011, 'humidity': 74}, 'visibility': 10000, 'wind': {'speed': 6.17, 'deg': 280}, 'clouds': {'all': 1}, 'dt': 1631836145, 'sys': {'type': 1, 'id': 4747, 'country': 'US', 'sunrise': 1631799952, 'sunset': 1631844446}, 'timezone': -25200, 'id': 5367788, 'name': 'Lompoc', 'cod': 200}
# Processing Record 49 of Set 1 | cerritos
# {'coord': {'lon': -118.0648, 'lat': 33.8583}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 296.49, 'feels_like': 296.47, 'temp_min': 291.39, 'temp_max': 305.34, 'pressure': 1011, 'humidity': 61}, 'visibility': 10000, 'wind': {'speed': 2.68, 'deg': 182, 'gust': 4.92}, 'clouds': {'all': 1}, 'dt': 1631836371, 'sys': {'type': 2, 'id': 2010205, 'country': 'US', 'sunrise': 1631799391, 'sunset': 1631843858}, 'timezone': -25200, 'id': 5335663, 'name': 'Cerritos', 'cod': 200}
# Processing Record 50 of Set 1 | havelock
# {'coord': {'lon': -76.9013, 'lat': 34.8791}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 298.44, 'feels_like': 299.32, 'temp_min': 297.03, 'temp_max': 300.14, 'pressure': 1016, 'humidity': 88}, 'visibility': 10000, 'wind': {'speed': 4.63, 'deg': 40}, 'clouds': {'all': 75}, 'dt': 1631836024, 'sys': {'type': 2, 'id': 2018017, 'country': 'US', 'sunrise': 1631789489, 'sunset': 1631834007}, 'timezone': -14400, 'id': 4470244, 'name': 'Havelock', 'cod': 200}
# Processing Record 1 of Set 2 | arraial+do+cabo
# {'coord': {'lon': -42.0278, 'lat': -22.9661}, 'weather': [{'id': 701, 'main': 'Mist', 'description': 'mist', 'icon': '50n'}], 'base': 'stations', 'main': {'temp': 295.13, 'feels_like': 295.68, 'temp_min': 295.13, 'temp_max': 295.13, 'pressure': 1024, 'humidity': 88}, 'visibility': 5000, 'wind': {'speed': 4.12, 'deg': 170}, 'clouds': {'all': 90}, 'dt': 1631835771, 'sys': {'type': 1, 'id': 8343, 'country': 'BR', 'sunrise': 1631781820, 'sunset': 1631824941}, 'timezone': -10800, 'id': 3471451, 'name': 'Arraial do Cabo', 'cod': 200}
# Processing Record 2 of Set 2 | belmonte
# {'coord': {'lon': -38.8828, 'lat': -15.8631}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'stations', 'main': {'temp': 298.43, 'feels_like': 299.23, 'temp_min': 298.43, 'temp_max': 298.43, 'pressure': 1022, 'humidity': 85, 'sea_level': 1022, 'grnd_level': 1021}, 'visibility': 10000, 'wind': {'speed': 3.46, 'deg': 102, 'gust': 3.96}, 'clouds': {'all': 37}, 'dt': 1631836372, 'sys': {'type': 1, 'id': 8422, 'country': 'BR', 'sunrise': 1631780991, 'sunset': 1631824261}, 'timezone': -10800, 'id': 3470137, 'name': 'Belmonte', 'cod': 200}
# Processing Record 3 of Set 2 | zhangjiakou
# {'coord': {'lon': 114.8794, 'lat': 40.81}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 289.09, 'feels_like': 288.36, 'temp_min': 289.09, 'temp_max': 289.09, 'pressure': 1018, 'humidity': 62, 'sea_level': 1018, 'grnd_level': 932}, 'visibility': 10000, 'wind': {'speed': 0.38, 'deg': 49, 'gust': 0.55}, 'clouds': {'all': 0}, 'dt': 1631836373, 'sys': {'country': 'CN', 'sunrise': 1631829769, 'sunset': 1631874451}, 'timezone': 28800, 'id': 2033196, 'name': 'Zhangjiakou', 'cod': 200}
# Processing Record 4 of Set 2 | east+london
# {'coord': {'lon': 27.9116, 'lat': -33.0153}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 287.14, 'feels_like': 286.27, 'temp_min': 287.14, 'temp_max': 287.14, 'pressure': 1025, 'humidity': 64, 'sea_level': 1025, 'grnd_level': 1020}, 'visibility': 10000, 'wind': {'speed': 6.44, 'deg': 271, 'gust': 10.01}, 'clouds': {'all': 64}, 'dt': 1631836065, 'sys': {'country': 'ZA', 'sunrise': 1631851484, 'sunset': 1631894470}, 'timezone': 7200, 'id': 1006984, 'name': 'East London', 'cod': 200}
# Processing Record 5 of Set 2 | ancud
# {'coord': {'lon': -73.8203, 'lat': -41.8697}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 282.89, 'feels_like': 280.36, 'temp_min': 282.89, 'temp_max': 283.39, 'pressure': 1018, 'humidity': 91, 'sea_level': 1018, 'grnd_level': 1012}, 'visibility': 10000, 'wind': {'speed': 5.14, 'deg': 331, 'gust': 8.81}, 'clouds': {'all': 100}, 'dt': 1631835993, 'sys': {'type': 1, 'id': 8512, 'country': 'CL', 'sunrise': 1631789676, 'sunset': 1631832341}, 'timezone': -10800, 'id': 3899695, 'name': 'Ancud', 'cod': 200}
# Processing Record 6 of Set 2 | stantsiya+gorchakovo
# {'cod': '404', 'message': 'city not found'}
# City not found. Skipping...
# Processing Record 7 of Set 2 | ribeira+grande
# {'coord': {'lon': -28.7, 'lat': 38.5167}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 295.48, 'feels_like': 295.96, 'temp_min': 295.48, 'temp_max': 295.48, 'pressure': 1028, 'humidity': 84, 'sea_level': 1028, 'grnd_level': 1028}, 'visibility': 10000, 'wind': {'speed': 2.15, 'deg': 10, 'gust': 3}, 'clouds': {'all': 95}, 'dt': 1631835767, 'sys': {'country': 'PT', 'sunrise': 1631777843, 'sunset': 1631822522}, 'timezone': 0, 'id': 3372707, 'name': 'Ribeira Grande', 'cod': 200}
# Processing Record 8 of Set 2 | nouakchott
# {'coord': {'lon': -15.9785, 'lat': 18.0858}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 302.11, 'feels_like': 306.16, 'temp_min': 302.11, 'temp_max': 302.11, 'pressure': 1013, 'humidity': 72, 'sea_level': 1013, 'grnd_level': 1012}, 'visibility': 10000, 'wind': {'speed': 5.18, 'deg': 315, 'gust': 6.54}, 'clouds': {'all': 98}, 'dt': 1631836147, 'sys': {'type': 1, 'id': 2482, 'country': 'MR', 'sunrise': 1631775121, 'sunset': 1631819140}, 'timezone': 0, 'id': 2377450, 'name': 'Nouakchott', 'cod': 200}
# Processing Record 9 of Set 2 | aflu
# {'cod': '404', 'message': 'city not found'}
# City not found. Skipping...
# Processing Record 10 of Set 2 | lebu
# {'coord': {'lon': -73.65, 'lat': -37.6167}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 282.79, 'feels_like': 280.94, 'temp_min': 282.79, 'temp_max': 282.79, 'pressure': 1021, 'humidity': 91, 'sea_level': 1021, 'grnd_level': 1017}, 'visibility': 10000, 'wind': {'speed': 3.52, 'deg': 195, 'gust': 5.91}, 'clouds': {'all': 0}, 'dt': 1631835957, 'sys': {'country': 'CL', 'sunrise': 1631789576, 'sunset': 1631832360}, 'timezone': -10800, 'id': 3883457, 'name': 'Lebu', 'cod': 200}
# Processing Record 11 of Set 2 | klaksvik
# {'coord': {'lon': -6.589, 'lat': 62.2266}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 285.66, 'feels_like': 285.5, 'temp_min': 285.66, 'temp_max': 285.66, 'pressure': 1003, 'humidity': 97, 'sea_level': 1003, 'grnd_level': 1001}, 'visibility': 1711, 'wind': {'speed': 14.34, 'deg': 150, 'gust': 19.79}, 'clouds': {'all': 100}, 'dt': 1631836375, 'sys': {'type': 1, 'id': 1596, 'country': 'FO', 'sunrise': 1631858235, 'sunset': 1631904276}, 'timezone': 3600, 'id': 2618795, 'name': 'Klaksvík', 'cod': 200}
# Processing Record 12 of Set 2 | san+cristobal
# {'coord': {'lon': -72.225, 'lat': 7.7669}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 297.25, 'feels_like': 298.27, 'temp_min': 297.25, 'temp_max': 297.25, 'pressure': 1016, 'humidity': 98, 'sea_level': 1016, 'grnd_level': 915}, 'visibility': 3677, 'wind': {'speed': 1.54, 'deg': 117, 'gust': 2.92}, 'clouds': {'all': 70}, 'dt': 1631836159, 'sys': {'type': 1, 'id': 8587, 'country': 'VE', 'sunrise': 1631788743, 'sunset': 1631832509}, 'timezone': -14400, 'id': 3628473, 'name': 'San Cristobal', 'cod': 200}
# Processing Record 13 of Set 2 | mar+del+plata
# {'coord': {'lon': -57.5575, 'lat': -38.0023}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 290.16, 'feels_like': 289.46, 'temp_min': 290.16, 'temp_max': 290.16, 'pressure': 1020, 'humidity': 59}, 'visibility': 10000, 'wind': {'speed': 2.57, 'deg': 360}, 'clouds': {'all': 0}, 'dt': 1631836005, 'sys': {'type': 1, 'id': 8305, 'country': 'AR', 'sunrise': 1631785723, 'sunset': 1631828490}, 'timezone': -10800, 'id': 3430863, 'name': 'Mar del Plata', 'cod': 200}
# Processing Record 14 of Set 2 | samusu
# {'cod': '404', 'message': 'city not found'}
# City not found. Skipping...
# Processing Record 15 of Set 2 | saint-philippe
# {'coord': {'lon': 55.7679, 'lat': -21.3585}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}], 'base': 'stations', 'main': {'temp': 292.82, 'feels_like': 293.01, 'temp_min': 292.71, 'temp_max': 293.9, 'pressure': 1017, 'humidity': 83, 'sea_level': 1017, 'grnd_level': 1011}, 'visibility': 10000, 'wind': {'speed': 2.83, 'deg': 39, 'gust': 3.22}, 'rain': {'1h': 0.19}, 'clouds': {'all': 44}, 'dt': 1631836103, 'sys': {'type': 1, 'id': 2127, 'country': 'RE', 'sunrise': 1631844690, 'sunset': 1631887897}, 'timezone': 14400, 'id': 935215, 'name': 'Saint-Philippe', 'cod': 200}
# Processing Record 16 of Set 2 | polis
# {'coord': {'lon': 32.4264, 'lat': 35.0367}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 295.05, 'feels_like': 295.05, 'temp_min': 295.05, 'temp_max': 295.05, 'pressure': 1011, 'humidity': 67, 'sea_level': 1011, 'grnd_level': 1008}, 'visibility': 10000, 'wind': {'speed': 1.32, 'deg': 148, 'gust': 1.67}, 'clouds': {'all': 0}, 'dt': 1631836377, 'sys': {'type': 1, 'id': 6374, 'country': 'CY', 'sunrise': 1631849677, 'sunset': 1631894110}, 'timezone': 10800, 'id': 146137, 'name': 'Polis', 'cod': 200}
# Processing Record 17 of Set 2 | geraldton
# {'coord': {'lon': 114.6, 'lat': -28.7667}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 285.38, 'feels_like': 284.93, 'temp_min': 285.38, 'temp_max': 285.38, 'pressure': 1023, 'humidity': 87}, 'visibility': 10000, 'wind': {'speed': 0, 'deg': 0}, 'clouds': {'all': 75}, 'dt': 1631836050, 'sys': {'type': 1, 'id': 9522, 'country': 'AU', 'sunrise': 1631830653, 'sunset': 1631873701}, 'timezone': 28800, 'id': 2070998, 'name': 'Geraldton', 'cod': 200}
# Processing Record 18 of Set 2 | camopi
# {'coord': {'lon': -52.3158, 'lat': 3.1655}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 294.85, 'feels_like': 295.66, 'temp_min': 294.85, 'temp_max': 294.85, 'pressure': 1015, 'humidity': 99, 'sea_level': 1015, 'grnd_level': 1003}, 'visibility': 10000, 'wind': {'speed': 1.17, 'deg': 120, 'gust': 2.36}, 'clouds': {'all': 58}, 'dt': 1631836377, 'sys': {'country': 'GF', 'sunrise': 1631784016, 'sunset': 1631827682}, 'timezone': -10800, 'id': 3382226, 'name': 'Camopi', 'cod': 200}
# Processing Record 19 of Set 2 | candolim
# {'coord': {'lon': 73.7626, 'lat': 15.5181}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 299.15, 'feels_like': 299.15, 'temp_min': 299.15, 'temp_max': 299.15, 'pressure': 1005, 'humidity': 89}, 'visibility': 6000, 'wind': {'speed': 2.06, 'deg': 250}, 'clouds': {'all': 75}, 'dt': 1631836378, 'sys': {'type': 1, 'id': 9233, 'country': 'IN', 'sunrise': 1631840018, 'sunset': 1631883933}, 'timezone': 19800, 'id': 1274989, 'name': 'Candolim', 'cod': 200}
# Processing Record 20 of Set 2 | deputatskiy
# {'coord': {'lon': 139.9, 'lat': 69.3}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 278.51, 'feels_like': 278.51, 'temp_min': 278.51, 'temp_max': 278.51, 'pressure': 1005, 'humidity': 76, 'sea_level': 1005, 'grnd_level': 937}, 'visibility': 10000, 'wind': {'speed': 0.83, 'deg': 84, 'gust': 0.84}, 'clouds': {'all': 100}, 'dt': 1631836254, 'sys': {'country': 'RU', 'sunrise': 1631822455, 'sunset': 1631869759}, 'timezone': 36000, 'id': 2028164, 'name': 'Deputatsky', 'cod': 200}
# Processing Record 21 of Set 2 | mutsu
# {'coord': {'lon': 141.2169, 'lat': 41.2894}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 292.33, 'feels_like': 292.03, 'temp_min': 292.33, 'temp_max': 292.33, 'pressure': 1017, 'humidity': 66, 'sea_level': 1017, 'grnd_level': 1016}, 'visibility': 10000, 'wind': {'speed': 5.05, 'deg': 135, 'gust': 6.34}, 'clouds': {'all': 99}, 'dt': 1631836379, 'sys': {'type': 1, 'id': 7974, 'country': 'JP', 'sunrise': 1631823434, 'sunset': 1631868148}, 'timezone': 32400, 'id': 2127878, 'name': 'Mutsu', 'cod': 200}
# Processing Record 22 of Set 2 | sao+filipe
# {'coord': {'lon': -24.4956, 'lat': 14.8961}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 299.46, 'feels_like': 299.46, 'temp_min': 299.46, 'temp_max': 299.46, 'pressure': 1016, 'humidity': 81, 'sea_level': 1016, 'grnd_level': 1004}, 'visibility': 10000, 'wind': {'speed': 3.68, 'deg': 63, 'gust': 5.3}, 'clouds': {'all': 100}, 'dt': 1631835780, 'sys': {'country': 'CV', 'sunrise': 1631777205, 'sunset': 1631821142}, 'timezone': -3600, 'id': 3374210, 'name': 'São Filipe', 'cod': 200}
# Processing Record 23 of Set 2 | puerto+ayora
# {'coord': {'lon': -90.3518, 'lat': -0.7393}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 292.9, 'feels_like': 293.41, 'temp_min': 292.9, 'temp_max': 292.9, 'pressure': 1012, 'humidity': 95}, 'visibility': 10000, 'wind': {'speed': 0.89, 'deg': 113, 'gust': 2.24}, 'clouds': {'all': 52}, 'dt': 1631835988, 'sys': {'type': 2, 'id': 2005652, 'country': 'EC', 'sunrise': 1631793183, 'sunset': 1631836767}, 'timezone': -21600, 'id': 3652764, 'name': 'Puerto Ayora', 'cod': 200}
# Processing Record 24 of Set 2 | sarahan
# {'coord': {'lon': 77.8, 'lat': 31.5167}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}], 'base': 'stations', 'main': {'temp': 287.49, 'feels_like': 287.23, 'temp_min': 287.49, 'temp_max': 287.49, 'pressure': 1011, 'humidity': 86, 'sea_level': 1011, 'grnd_level': 790}, 'visibility': 10000, 'wind': {'speed': 1.23, 'deg': 68, 'gust': 1.26}, 'clouds': {'all': 17}, 'dt': 1631836380, 'sys': {'country': 'IN', 'sunrise': 1631838840, 'sunset': 1631883174}, 'timezone': 19800, 'id': 1257277, 'name': 'Sarāhan', 'cod': 200}
# Processing Record 25 of Set 2 | luang+prabang
# {'coord': {'lon': 102.1347, 'lat': 19.8856}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 296.64, 'feels_like': 297.53, 'temp_min': 296.64, 'temp_max': 296.64, 'pressure': 1011, 'humidity': 95, 'sea_level': 1011, 'grnd_level': 977}, 'visibility': 10000, 'wind': {'speed': 0.32, 'deg': 169, 'gust': 0.74}, 'clouds': {'all': 100}, 'dt': 1631836380, 'sys': {'country': 'LA', 'sunrise': 1631833157, 'sunset': 1631877179}, 'timezone': 25200, 'id': 1655559, 'name': 'Luang Prabang', 'cod': 200}
# Processing Record 26 of Set 2 | aklavik
# {'coord': {'lon': -135.0107, 'lat': 68.2191}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': 286.15, 'feels_like': 285.02, 'temp_min': 286.15, 'temp_max': 288.61, 'pressure': 1003, 'humidity': 58}, 'visibility': 10000, 'wind': {'speed': 3.09, 'deg': 150}, 'clouds': {'all': 20}, 'dt': 1631836000, 'sys': {'type': 1, 'id': 821, 'country': 'CA', 'sunrise': 1631802092, 'sunset': 1631849290}, 'timezone': -21600, 'id': 5882953, 'name': 'Aklavik', 'cod': 200}
# Processing Record 27 of Set 2 | tiksi
# {'coord': {'lon': 128.8694, 'lat': 71.6872}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 277.45, 'feels_like': 274.11, 'temp_min': 277.45, 'temp_max': 277.45, 'pressure': 1008, 'humidity': 91, 'sea_level': 1008, 'grnd_level': 1003}, 'visibility': 10000, 'wind': {'speed': 4.07, 'deg': 80, 'gust': 4.16}, 'clouds': {'all': 96}, 'dt': 1631836001, 'sys': {'country': 'RU', 'sunrise': 1631824826, 'sunset': 1631872681}, 'timezone': 32400, 'id': 2015306, 'name': 'Tiksi', 'cod': 200}
# Processing Record 28 of Set 2 | taolanaro
# {'cod': '404', 'message': 'city not found'}
# City not found. Skipping...
# Processing Record 29 of Set 2 | tuktoyaktuk
# {'coord': {'lon': -133.0374, 'lat': 69.4541}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': 286.15, 'feels_like': 285.12, 'temp_min': 286.15, 'temp_max': 286.15, 'pressure': 1004, 'humidity': 62}, 'visibility': 10000, 'wind': {'speed': 4.63, 'deg': 180}, 'clouds': {'all': 20}, 'dt': 1631836291, 'sys': {'type': 1, 'id': 942, 'country': 'CA', 'sunrise': 1631801488, 'sunset': 1631848946}, 'timezone': -21600, 'id': 6170031, 'name': 'Tuktoyaktuk', 'cod': 200}
# Processing Record 30 of Set 2 | priiskovyy
# {'coord': {'lon': 116.6333, 'lat': 51.9333}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': 282.58, 'feels_like': 281.51, 'temp_min': 282.58, 'temp_max': 282.58, 'pressure': 1013, 'humidity': 75, 'sea_level': 1013, 'grnd_level': 952}, 'visibility': 10000, 'wind': {'speed': 2.21, 'deg': 278, 'gust': 5.24}, 'clouds': {'all': 15}, 'dt': 1631836382, 'sys': {'country': 'RU', 'sunrise': 1631829059, 'sunset': 1631874320}, 'timezone': 32400, 'id': 2017632, 'name': 'Priiskovyy', 'cod': 200}
# Processing Record 31 of Set 2 | khorinsk
# {'coord': {'lon': 109.7726, 'lat': 52.1657}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 281.95, 'feels_like': 281.95, 'temp_min': 281.95, 'temp_max': 281.95, 'pressure': 1016, 'humidity': 78, 'sea_level': 1016, 'grnd_level': 938}, 'visibility': 10000, 'wind': {'speed': 0.46, 'deg': 338, 'gust': 0.84}, 'clouds': {'all': 77}, 'dt': 1631836382, 'sys': {'country': 'RU', 'sunrise': 1631830699, 'sunset': 1631875972}, 'timezone': 28800, 'id': 2022304, 'name': 'Khorinsk', 'cod': 200}
# Processing Record 32 of Set 2 | ingham
# {'coord': {'lon': -84.3833, 'lat': 42.6}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 294.17, 'feels_like': 294.05, 'temp_min': 290.81, 'temp_max': 297.25, 'pressure': 1020, 'humidity': 66}, 'visibility': 10000, 'wind': {'speed': 3.09, 'deg': 120}, 'clouds': {'all': 1}, 'dt': 1631836085, 'sys': {'type': 1, 'id': 6016, 'country': 'US', 'sunrise': 1631791125, 'sunset': 1631835961}, 'timezone': -14400, 'id': 4997130, 'name': 'Ingham', 'cod': 200}
# Processing Record 33 of Set 2 | kargasok
# {'coord': {'lon': 80.8572, 'lat': 59.0556}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 285.04, 'feels_like': 284.79, 'temp_min': 285.04, 'temp_max': 285.04, 'pressure': 995, 'humidity': 96, 'sea_level': 995, 'grnd_level': 989}, 'visibility': 10000, 'wind': {'speed': 5.33, 'deg': 167, 'gust': 11.86}, 'clouds': {'all': 100}, 'dt': 1631836383, 'sys': {'country': 'RU', 'sunrise': 1631837376, 'sunset': 1631883171}, 'timezone': 25200, 'id': 1504382, 'name': 'Kargasok', 'cod': 200}
# Processing Record 34 of Set 2 | arman
# {'coord': {'lon': 150.1667, 'lat': 59.7}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 286.12, 'feels_like': 285.3, 'temp_min': 286.12, 'temp_max': 286.12, 'pressure': 1014, 'humidity': 70, 'sea_level': 1014, 'grnd_level': 1012}, 'visibility': 10000, 'wind': {'speed': 1.24, 'deg': 125, 'gust': 1.95}, 'clouds': {'all': 5}, 'dt': 1631836383, 'sys': {'country': 'RU', 'sunrise': 1631820684, 'sunset': 1631866603}, 'timezone': 39600, 'id': 2127060, 'name': "Arman'", 'cod': 200}
# Processing Record 35 of Set 2 | pleshanovo
# ...
# Processing Record 17 of Set 15 | sibolga
# {'coord': {'lon': 98.7792, 'lat': 1.7427}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 298.02, 'feels_like': 298.7, 'temp_min': 298.02, 'temp_max': 298.02, 'pressure': 1010, 'humidity': 82, 'sea_level': 1010, 'grnd_level': 1009}, 'visibility': 10000, 'wind': {'speed': 1.19, 'deg': 50, 'gust': 1.22}, 'clouds': {'all': 65}, 'dt': 1631835828, 'sys': {'country': 'ID', 'sunrise': 1631834157, 'sunset': 1631877790}, 'timezone': 25200, 'id': 1213855, 'name': 'Sibolga', 'cod': 200}
# Processing Record 18 of Set 15 | bogandinskiy
# {'coord': {'lon': 65.8938, 'lat': 56.8937}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 276.3, 'feels_like': 272.86, 'temp_min': 276.3, 'temp_max': 276.3, 'pressure': 997, 'humidity': 83, 'sea_level': 997, 'grnd_level': 989}, 'visibility': 10000, 'wind': {'speed': 3.81, 'deg': 240, 'gust': 6.21}, 'clouds': {'all': 88}, 'dt': 1631836635, 'sys': {'type': 1, 'id': 8988, 'country': 'RU', 'sunrise': 1631841069, 'sunset': 1631886659}, 'timezone': 18000, 'id': 1509902, 'name': 'Bogandinskiy', 'cod': 200}
# Processing Record 19 of Set 15 | nizhnedevitsk
# {'coord': {'lon': 38.3657, 'lat': 51.5419}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'stations', 'main': {'temp': 276.18, 'feels_like': 276.18, 'temp_min': 276.18, 'temp_max': 276.18, 'pressure': 1020, 'humidity': 62, 'sea_level': 1020, 'grnd_level': 1001}, 'visibility': 10000, 'wind': {'speed': 0.58, 'deg': 35, 'gust': 0.68}, 'clouds': {'all': 33}, 'dt': 1631836636, 'sys': {'type': 1, 'id': 9034, 'country': 'RU', 'sunrise': 1631847876, 'sunset': 1631893062}, 'timezone': 10800, 'id': 521148, 'name': 'Nizhnedevitsk', 'cod': 200}
# Processing Record 20 of Set 15 | palauig
# {'coord': {'lon': 119.9045, 'lat': 15.435}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 300.54, 'feels_like': 302.99, 'temp_min': 300.54, 'temp_max': 300.54, 'pressure': 1009, 'humidity': 73, 'sea_level': 1009, 'grnd_level': 1008}, 'visibility': 10000, 'wind': {'speed': 0.92, 'deg': 94, 'gust': 1.17}, 'clouds': {'all': 99}, 'dt': 1631836636, 'sys': {'country': 'PH', 'sunrise': 1631828945, 'sunset': 1631872864}, 'timezone': 28800, 'id': 1696188, 'name': 'Palauig', 'cod': 200}
# Processing Record 21 of Set 15 | batemans+bay
# {'coord': {'lon': 150.1833, 'lat': -35.7167}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 288.11, 'feels_like': 286.99, 'temp_min': 288.1, 'temp_max': 291.59, 'pressure': 1020, 'humidity': 51, 'sea_level': 1020, 'grnd_level': 1018}, 'visibility': 10000, 'wind': {'speed': 2.57, 'deg': 41, 'gust': 3.87}, 'clouds': {'all': 0}, 'dt': 1631835980, 'sys': {'type': 2, 'id': 2010627, 'country': 'AU', 'sunrise': 1631822198, 'sunset': 1631865081}, 'timezone': 36000, 'id': 2176639, 'name': 'Batemans Bay', 'cod': 200}
# Processing Record 22 of Set 15 | anshun
# {'coord': {'lon': 105.9333, 'lat': 26.25}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 291.55, 'feels_like': 291.95, 'temp_min': 291.55, 'temp_max': 291.55, 'pressure': 1011, 'humidity': 96, 'sea_level': 1011, 'grnd_level': 863}, 'visibility': 10000, 'wind': {'speed': 1.28, 'deg': 167, 'gust': 3.85}, 'clouds': {'all': 100}, 'dt': 1631836637, 'sys': {'country': 'CN', 'sunrise': 1631832163, 'sunset': 1631876351}, 'timezone': 28800, 'id': 1817968, 'name': 'Anshun', 'cod': 200}
# Processing Record 23 of Set 15 | shahreza
# {'coord': {'lon': 51.8794, 'lat': 32.0339}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 291.27, 'feels_like': 289.53, 'temp_min': 291.27, 'temp_max': 291.27, 'pressure': 1009, 'humidity': 15, 'sea_level': 1009, 'grnd_level': 820}, 'visibility': 10000, 'wind': {'speed': 1.04, 'deg': 228, 'gust': 0.97}, 'clouds': {'all': 0}, 'dt': 1631836638, 'sys': {'country': 'IR', 'sunrise': 1631845055, 'sunset': 1631889398}, 'timezone': 16200, 'id': 417594, 'name': 'Shahreza', 'cod': 200}
# Processing Record 24 of Set 15 | matara
# {'coord': {'lon': 80.5353, 'lat': 5.9485}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 298.7, 'feels_like': 299.66, 'temp_min': 298.7, 'temp_max': 298.7, 'pressure': 1008, 'humidity': 90, 'sea_level': 1008, 'grnd_level': 1006}, 'visibility': 10000, 'wind': {'speed': 3.25, 'deg': 275, 'gust': 7.12}, 'clouds': {'all': 99}, 'dt': 1631836638, 'sys': {'country': 'LK', 'sunrise': 1631838494, 'sunset': 1631882208}, 'timezone': 19800, 'id': 1235846, 'name': 'Matara', 'cod': 200}
# Processing Record 25 of Set 15 | maarianhamina
# {'coord': {'lon': 19.9348, 'lat': 60.0973}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}], 'base': 'stations', 'main': {'temp': 282.07, 'feels_like': 280.64, 'temp_min': 282.07, 'temp_max': 282.07, 'pressure': 1020, 'humidity': 53, 'sea_level': 1020, 'grnd_level': 1018}, 'visibility': 10000, 'wind': {'speed': 2.57, 'deg': 70}, 'clouds': {'all': 20}, 'dt': 1631836639, 'sys': {'type': 1, 'id': 1347, 'country': 'AX', 'sunrise': 1631851970, 'sunset': 1631897812}, 'timezone': 10800, 'id': 3041732, 'name': 'Mariehamn', 'cod': 200}
# Processing Record 26 of Set 15 | ndele
# {'coord': {'lon': 20.6473, 'lat': 8.4109}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 294.75, 'feels_like': 295.47, 'temp_min': 294.75, 'temp_max': 294.75, 'pressure': 1010, 'humidity': 96, 'sea_level': 1010, 'grnd_level': 952}, 'visibility': 10000, 'wind': {'speed': 1.63, 'deg': 207, 'gust': 1.77}, 'clouds': {'all': 100}, 'dt': 1631836080, 'sys': {'country': 'CF', 'sunrise': 1631852840, 'sunset': 1631896600}, 'timezone': 3600, 'id': 237379, 'name': 'Ndélé', 'cod': 200}
# Processing Record 27 of Set 15 | barkly+west
# {'coord': {'lon': 24.5215, 'lat': -28.5354}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 279.75, 'feels_like': 275.91, 'temp_min': 279.75, 'temp_max': 279.75, 'pressure': 1022, 'humidity': 44, 'sea_level': 1022, 'grnd_level': 896}, 'visibility': 10000, 'wind': {'speed': 6.46, 'deg': 128, 'gust': 12.52}, 'clouds': {'all': 0}, 'dt': 1631836640, 'sys': {'type': 1, 'id': 1928, 'country': 'ZA', 'sunrise': 1631852252, 'sunset': 1631895330}, 'timezone': 7200, 'id': 1021040, 'name': 'Barkly West', 'cod': 200}
# Processing Record 28 of Set 15 | haibowan
# {'cod': '404', 'message': 'city not found'}
# City not found. Skipping...
# Processing Record 29 of Set 15 | ha+tinh
# {'coord': {'lon': 105.9, 'lat': 18.3333}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 299.29, 'feels_like': 299.29, 'temp_min': 299.29, 'temp_max': 299.29, 'pressure': 1009, 'humidity': 89, 'sea_level': 1009, 'grnd_level': 1008}, 'visibility': 10000, 'wind': {'speed': 0.98, 'deg': 226, 'gust': 1.16}, 'clouds': {'all': 100}, 'dt': 1631836640, 'sys': {'country': 'VN', 'sunrise': 1631832272, 'sunset': 1631876257}, 'timezone': 25200, 'id': 1581047, 'name': 'Ha Tinh', 'cod': 200}
# Processing Record 30 of Set 15 | bijawar
# {'coord': {'lon': 79.5, 'lat': 24.6333}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 296.33, 'feels_like': 297.16, 'temp_min': 296.33, 'temp_max': 296.33, 'pressure': 999, 'humidity': 94, 'sea_level': 999, 'grnd_level': 960}, 'visibility': 10000, 'wind': {'speed': 4.54, 'deg': 219, 'gust': 9.86}, 'clouds': {'all': 100}, 'dt': 1631836641, 'sys': {'country': 'IN', 'sunrise': 1631838530, 'sunset': 1631882668}, 'timezone': 19800, 'id': 1275694, 'name': 'Bijāwar', 'cod': 200}
# Processing Record 31 of Set 15 | brae
# {'coord': {'lon': -1.353, 'lat': 60.3964}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 287.1, 'feels_like': 286.95, 'temp_min': 287.1, 'temp_max': 287.1, 'pressure': 1011, 'humidity': 92, 'sea_level': 1011, 'grnd_level': 1010}, 'visibility': 10000, 'wind': {'speed': 6.57, 'deg': 154, 'gust': 12.07}, 'clouds': {'all': 92}, 'dt': 1631836641, 'sys': {'type': 1, 'id': 1438, 'country': 'GB', 'sunrise': 1631857073, 'sunset': 1631902925}, 'timezone': 3600, 'id': 2654970, 'name': 'Brae', 'cod': 200}
# Processing Record 32 of Set 15 | bilma
# {'coord': {'lon': 12.9164, 'lat': 18.6853}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 304.57, 'feels_like': 302.47, 'temp_min': 304.57, 'temp_max': 304.57, 'pressure': 1009, 'humidity': 16, 'sea_level': 1009, 'grnd_level': 970}, 'visibility': 10000, 'wind': {'speed': 4.73, 'deg': 8, 'gust': 6.9}, 'clouds': {'all': 1}, 'dt': 1631836174, 'sys': {'country': 'NE', 'sunrise': 1631854586, 'sunset': 1631898564}, 'timezone': 3600, 'id': 2446796, 'name': 'Bilma', 'cod': 200}
# Processing Record 33 of Set 15 | richards+bay
# {'coord': {'lon': 32.0377, 'lat': -28.783}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}], 'base': 'stations', 'main': {'temp': 289.1, 'feels_like': 289.05, 'temp_min': 289.1, 'temp_max': 289.1, 'pressure': 1022, 'humidity': 88, 'sea_level': 1022, 'grnd_level': 1021}, 'visibility': 10000, 'wind': {'speed': 5.52, 'deg': 200, 'gust': 9.99}, 'rain': {'1h': 0.61}, 'clouds': {'all': 100}, 'dt': 1631836642, 'sys': {'country': 'ZA', 'sunrise': 1631850452, 'sunset': 1631893523}, 'timezone': 7200, 'id': 962367, 'name': 'Richards Bay', 'cod': 200}
# Processing Record 34 of Set 15 | pokhara
# {'coord': {'lon': 83.9833, 'lat': 28.2333}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 292.24, 'feels_like': 292.71, 'temp_min': 292.24, 'temp_max': 292.24, 'pressure': 1009, 'humidity': 96, 'sea_level': 1009, 'grnd_level': 908}, 'visibility': 10000, 'wind': {'speed': 0.55, 'deg': 259, 'gust': 0.77}, 'clouds': {'all': 100}, 'dt': 1631836642, 'sys': {'country': 'NP', 'sunrise': 1631837404, 'sunset': 1631881642}, 'timezone': 20700, 'id': 1282898, 'name': 'Pokhara', 'cod': 200}
# Processing Record 35 of Set 15 | ponta+delgada
# {'coord': {'lon': -25.6667, 'lat': 37.7333}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}], 'base': 'stations', 'main': {'temp': 294.55, 'feels_like': 294.91, 'temp_min': 294.55, 'temp_max': 294.55, 'pressure': 1028, 'humidity': 83}, 'visibility': 10000, 'wind': {'speed': 1.03, 'deg': 0}, 'clouds': {'all': 20}, 'dt': 1631836643, 'sys': {'type': 1, 'id': 6899, 'country': 'PT', 'sunrise': 1631777131, 'sunset': 1631821779}, 'timezone': 0, 'id': 3372783, 'name': 'Ponta Delgada', 'cod': 200}
# Processing Record 36 of Set 15 | fuyu
# {'coord': {'lon': 124.8167, 'lat': 45.1833}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 290.2, 'feels_like': 289.66, 'temp_min': 290.2, 'temp_max': 290.2, 'pressure': 1016, 'humidity': 65, 'sea_level': 1016, 'grnd_level': 999}, 'visibility': 10000, 'wind': {'speed': 3.39, 'deg': 219, 'gust': 4.86}, 'clouds': {'all': 0}, 'dt': 1631836643, 'sys': {'country': 'CN', 'sunrise': 1631827283, 'sunset': 1631872168}, 'timezone': 28800, 'id': 2037335, 'name': 'Fuyu', 'cod': 200}
# Processing Record 37 of Set 15 | zinder
# {'coord': {'lon': 8.9881, 'lat': 13.8072}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'stations', 'main': {'temp': 302.03, 'feels_like': 302.11, 'temp_min': 302.03, 'temp_max': 302.03, 'pressure': 1010, 'humidity': 45, 'sea_level': 1010, 'grnd_level': 959}, 'visibility': 10000, 'wind': {'speed': 3.56, 'deg': 274, 'gust': 5.96}, 'clouds': {'all': 44}, 'dt': 1631836644, 'sys': {'country': 'NE', 'sunrise': 1631855583, 'sunset': 1631899452}, 'timezone': 3600, 'id': 2437798, 'name': 'Zinder', 'cod': 200}
# Processing Record 38 of Set 15 | nguiu
# {'cod': '404', 'message': 'city not found'}
# City not found. Skipping...
# Processing Record 39 of Set 15 | pulandian
# {'coord': {'lon': 121.9669, 'lat': 39.3953}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'}], 'base': 'stations', 'main': {'temp': 293.22, 'feels_like': 293.32, 'temp_min': 293.22, 'temp_max': 293.22, 'pressure': 1013, 'humidity': 78, 'sea_level': 1013, 'grnd_level': 1011}, 'visibility': 10000, 'wind': {'speed': 3.48, 'deg': 2, 'gust': 4.42}, 'rain': {'1h': 0.15}, 'clouds': {'all': 100}, 'dt': 1631836645, 'sys': {'type': 1, 'id': 9679, 'country': 'CN', 'sunrise': 1631828096, 'sunset': 1631872724}, 'timezone': 28800, 'id': 1798490, 'name': 'Pulandian', 'cod': 200}
# Processing Record 40 of Set 15 | porbandar
# {'coord': {'lon': 69.6093, 'lat': 21.6422}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 300.08, 'feels_like': 303.49, 'temp_min': 300.08, 'temp_max': 300.08, 'pressure': 1002, 'humidity': 88, 'sea_level': 1002, 'grnd_level': 1001}, 'visibility': 10000, 'wind': {'speed': 6.25, 'deg': 220, 'gust': 7.82}, 'clouds': {'all': 100}, 'dt': 1631836645, 'sys': {'country': 'IN', 'sunrise': 1631840943, 'sunset': 1631885002}, 'timezone': 19800, 'id': 1259395, 'name': 'Porbandar', 'cod': 200}
# Processing Record 41 of Set 15 | de+aar
# {'coord': {'lon': 24.0123, 'lat': -30.6497}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 279.04, 'feels_like': 275.76, 'temp_min': 279.04, 'temp_max': 279.04, 'pressure': 1025, 'humidity': 77, 'sea_level': 1025, 'grnd_level': 882}, 'visibility': 10000, 'wind': {'speed': 4.67, 'deg': 129, 'gust': 9.11}, 'clouds': {'all': 0}, 'dt': 1631836646, 'sys': {'country': 'ZA', 'sunrise': 1631852395, 'sunset': 1631895431}, 'timezone': 7200, 'id': 1011632, 'name': 'De Aar', 'cod': 200}
# Processing Record 42 of Set 15 | mackay
# {'coord': {'lon': 149.2, 'lat': -21.15}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 296.14, 'feels_like': 296.27, 'temp_min': 296.14, 'temp_max': 298.17, 'pressure': 1021, 'humidity': 68}, 'visibility': 10000, 'wind': {'speed': 2.06, 'deg': 170}, 'clouds': {'all': 40}, 'dt': 1631836646, 'sys': {'type': 1, 'id': 9498, 'country': 'AU', 'sunrise': 1631822279, 'sunset': 1631865472}, 'timezone': 36000, 'id': 2159220, 'name': 'Mackay', 'cod': 200}
# Processing Record 43 of Set 15 | dongsheng
# {'coord': {'lon': 109.9776, 'lat': 39.8161}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 287.24, 'feels_like': 286.3, 'temp_min': 287.24, 'temp_max': 287.24, 'pressure': 1017, 'humidity': 61, 'sea_level': 1017, 'grnd_level': 859}, 'visibility': 10000, 'wind': {'speed': 2.2, 'deg': 83, 'gust': 2.94}, 'clouds': {'all': 90}, 'dt': 1631836251, 'sys': {'country': 'CN', 'sunrise': 1631830967, 'sunset': 1631875606}, 'timezone': 28800, 'id': 1812256, 'name': 'Dongsheng', 'cod': 200}
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0      Rikitea -23.1203 -134.9692    296.64        71          52        6.39
# 1    Cape+Town -33.9258   18.4232    286.42        71           0        1.79
# 2      Mataura -46.1927  168.8643    280.64        51          32        2.74
# 3     Victoria  22.2855  114.1577    302.22        82          52        0.45
# 4    Mahebourg -20.4081   57.7000    294.31        94          75        1.54
# 5     Khatanga  71.9667  102.5000    273.02        89         100        1.61
# 6       Dikson  73.5069   80.5464    274.89        77         100        7.36
# 7  Henties+Bay -22.1160   14.2845    284.18        90          16        1.13
# 8       Pirgos  35.1167   25.7178    298.42        53           0        3.91
# 9       Atuona  -9.8000 -139.0333    298.28        79          18        7.11
#
#   Country                 Date       Description
# 0      PF  2021-09-16 23:43:02        light rain
# 1      ZA  2021-09-16 23:44:02         clear sky
# 2      NZ  2021-09-16 23:46:29  scattered clouds
# 3      HK  2021-09-16 23:51:16        light rain
# 4      MU  2021-09-16 23:46:20     broken clouds
# 5      RU  2021-09-16 23:42:21   overcast clouds
# 6      RU  2021-09-16 23:47:58   overcast clouds
# 7      NA  2021-09-16 23:46:24        few clouds
# 8      GR  2021-09-16 23:47:11         clear sky
# 9      PF  2021-09-16 23:47:28        light rain

# %%
# Create the output file (CSV).
output_data_file = "weather_database/Weatherpy_database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
